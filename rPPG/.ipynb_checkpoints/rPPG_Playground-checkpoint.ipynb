# %%
from pyVHR.analysis.pipeline import Pipeline
from realtime_pipeline import Realtime_Pipeline
import matplotlib.pyplot as plt
# Out:
# OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %% [markdown]
# ### Execution Time Comparison

# %%
import statistics
realtime_pipe = Realtime_Pipeline()
holistic_skin_extraction_execution_times = realtime_pipe.run_realtime_pipeline(is_test=True, advanced_skin_extraction=True)
plt.figure()
plt.plot(holistic_skin_extraction_execution_times)
plt.show()
print('mean_execution_time:', statistics.mean(holistic_skin_extraction_execution_times))
# Out:
# Redetecing
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Tracking
# Lost Face
# Redetecing
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# mean_execution_time: 0.6101930297789027

# %%
basic_skin_extraction_execution_times = realtime_pipe.run_realtime_pipeline(is_test=True, advanced_skin_extraction=False)
plt.figure()
plt.plot(basic_skin_extraction_execution_times)
plt.show()
print('mean_execution_time:', statistics.mean(basic_skin_extraction_execution_times))
# Out:
# Redetecing
# Tracking
# Lost Face
# Redetecing
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# mean_execution_time: 0.00045272170520219645

# %%
plt.plot(basic_skin_extraction_execution_times, 'b')
plt.plot(holistic_skin_extraction_execution_times, 'g')
plt.show()

# %% [markdown]
# ### Skin Extraction Pixels Comparison (RGB Signal)

# %%
realtime_pipe = Realtime_Pipeline()
holistic_RGB_signal = realtime_pipe.run_realtime_pipeline(is_test=True, advanced_skin_extraction=True)
basic_RGB_signal = realtime_pipe.run_realtime_pipeline(is_test=True, advanced_skin_extraction=False)
R_holistic = [x[0] for x in holistic_RGB_signal]
G_holistic = [x[1] for x in holistic_RGB_signal]
B_holistic= [x[2] for x in holistic_RGB_signal]
R_basic = [x[0] for x in basic_RGB_signal]
G_basic = [x[1] for x in basic_RGB_signal]
B_basic= [x[2] for x in basic_RGB_signal]

plt.figure()
plt.plot(R_holistic, 'orange', label='holistic')
plt.plot(R_basic, 'darkorchid', label='basic')
plt.title('Red Signal')
plt.legend(loc="upper left")
plt.show()

plt.plot(G_holistic, 'orange', label='holistic')
plt.plot(G_basic, 'darkorchid', label='basic')
plt.title('Green Signal')
plt.legend(loc="upper left")
plt.show()

plt.plot(B_holistic, 'orange', label='holistic')
plt.plot(B_basic, 'darkorchid', label='basic')
plt.title('Blue Signal')
plt.legend(loc="upper left")
plt.show()
# Out:
# Redetecing
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Tracking
# Lost Face
# Redetecing
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Redetecing
# Tracking
# Lost Face
# Redetecing
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking
# Tracking

# %% [markdown]
# ### Accuracy Comparison
